# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('sensor_data_chennail_study.csv')
df.head()
# Out:
#                         _id       srvtime  DF_PM1  DF_PM25  DF_PM10  P_Id  \
# 0  628f2540fbfed37e61ad9b22  1.653548e+12     NaN      NaN      NaN   NaN
# 1  628f254bfbfed37e61ad9b2c  1.653548e+12     NaN      NaN      NaN   NaN
# 2  628f2555fbfed37e61ad9b37  1.653548e+12    10.0     14.0     18.0   NaN
# 3  628f2560fbfed37e61ad9b42  1.653548e+12     9.0     12.0     13.0   NaN
# 4  628f256afbfed37e61ad9b4d  1.653548e+12     9.0     13.0     15.0   NaN
#
#   name  lat  NSO  lon  ... pdop  D_Time  DHT_RH  DHT_TEMP  AHT_RH  AHT_TEMP  \
# 0  NaN  NaN  NaN  NaN  ...  NaN     NaN     NaN       NaN     NaN       NaN
# 1  NaN  NaN  NaN  NaN  ...  NaN     NaN     NaN       NaN     NaN       NaN
# 2  NaN  NaN  NaN  NaN  ...  NaN     NaN     NaN       NaN     NaN       NaN
# 3  NaN  NaN  NaN  NaN  ...  NaN     NaN     NaN       NaN     NaN       NaN
# 4  NaN  NaN  NaN  NaN  ...  NaN     NaN     NaN       NaN     NaN       NaN
#
#    SPS_PM1 SPS_PM25  SPS_PM4  SPS_PM10
# ...

# %%
df.shape
# Out:
# (91897, 26)

# %%
df['_id'].nunique()
# Out:
# 91897

# %%
#we can remove the _id coulmn as it is mongodb object
df.drop(columns=['_id'],inplace=True)
df
# Out:
#             srvtime  DF_PM1  DF_PM25  DF_PM10  P_Id name        lat  NSO  \
# 0      1.653548e+12     NaN      NaN      NaN   NaN  NaN        NaN  NaN
# 1      1.653548e+12     NaN      NaN      NaN   NaN  NaN        NaN  NaN
# 2      1.653548e+12    10.0     14.0     18.0   NaN  NaN        NaN  NaN
# 3      1.653548e+12     9.0     12.0     13.0   NaN  NaN        NaN  NaN
# 4      1.653548e+12     9.0     13.0     15.0   NaN  NaN        NaN  NaN
# ...             ...     ...      ...      ...   ...  ...        ...  ...
# 91892  1.653927e+12    22.0     31.0     41.0  57.0   M4  12.965772    N
# 91893  1.653927e+12   111.0    145.0    174.0  58.0   M4  12.965793    N
# 91894  1.653927e+12    70.0     87.0    105.0  59.0   M4  12.965595    N
# 91895  1.653927e+12    15.0     23.0     32.0  60.0   M4  12.965311    N
# 91896  1.653927e+12    14.0     18.0     26.0  61.0   M4  12.965468    N
#
#              lon  EWO  ...  pdop               D_Time  DHT_RH  DHT_TEMP  \
# ...

# %%
df.dtypes
# Out:
# srvtime     float64
# DF_PM1      float64
# DF_PM25     float64
# DF_PM10     float64
# P_Id        float64
# name         object
# lat         float64
# NSO          object
# lon         float64
# EWO          object
# Alt         float64
# sog         float64
# cog         float64
# hdop        float64
# vdop        float64
# pdop        float64
# D_Time       object
# DHT_RH      float64
# DHT_TEMP    float64
# AHT_RH      float64
# AHT_TEMP    float64
# SPS_PM1     float64
# SPS_PM25    float64
# SPS_PM4     float64
# SPS_PM10    float64
# dtype: object

# %%
#changing the D_Time to date object
df['D_Time']=pd.to_datetime(df['D_Time'])
df
# Out:
#             srvtime  DF_PM1  DF_PM25  DF_PM10  P_Id name        lat  NSO  \
# 0      1.653548e+12     NaN      NaN      NaN   NaN  NaN        NaN  NaN
# 1      1.653548e+12     NaN      NaN      NaN   NaN  NaN        NaN  NaN
# 2      1.653548e+12    10.0     14.0     18.0   NaN  NaN        NaN  NaN
# 3      1.653548e+12     9.0     12.0     13.0   NaN  NaN        NaN  NaN
# 4      1.653548e+12     9.0     13.0     15.0   NaN  NaN        NaN  NaN
# ...             ...     ...      ...      ...   ...  ...        ...  ...
# 91892  1.653927e+12    22.0     31.0     41.0  57.0   M4  12.965772    N
# 91893  1.653927e+12   111.0    145.0    174.0  58.0   M4  12.965793    N
# 91894  1.653927e+12    70.0     87.0    105.0  59.0   M4  12.965595    N
# 91895  1.653927e+12    15.0     23.0     32.0  60.0   M4  12.965311    N
# 91896  1.653927e+12    14.0     18.0     26.0  61.0   M4  12.965468    N
#
#              lon  EWO  ...  pdop              D_Time  DHT_RH  DHT_TEMP  \
# ...

# %%
df.drop(columns=['srvtime'],inplace=True)
df
# Out:
#        DF_PM1  DF_PM25  DF_PM10  P_Id name        lat  NSO        lon  EWO  \
# 0         NaN      NaN      NaN   NaN  NaN        NaN  NaN        NaN  NaN
# 1         NaN      NaN      NaN   NaN  NaN        NaN  NaN        NaN  NaN
# 2        10.0     14.0     18.0   NaN  NaN        NaN  NaN        NaN  NaN
# 3         9.0     12.0     13.0   NaN  NaN        NaN  NaN        NaN  NaN
# 4         9.0     13.0     15.0   NaN  NaN        NaN  NaN        NaN  NaN
# ...       ...      ...      ...   ...  ...        ...  ...        ...  ...
# 91892    22.0     31.0     41.0  57.0   M4  12.965772    N  80.203153    E
# 91893   111.0    145.0    174.0  58.0   M4  12.965793    N  80.202386    E
# 91894    70.0     87.0    105.0  59.0   M4  12.965595    N  80.201811    E
# 91895    15.0     23.0     32.0  60.0   M4  12.965311    N  80.201358    E
# 91896    14.0     18.0     26.0  61.0   M4  12.965468    N  80.200651    E
#
# ...

# %%
df.dtypes
# Out:
# DF_PM1             float64
# DF_PM25            float64
# DF_PM10            float64
# P_Id               float64
# name                object
# lat                float64
# NSO                 object
# lon                float64
# EWO                 object
# Alt                float64
# sog                float64
# cog                float64
# hdop               float64
# vdop               float64
# pdop               float64
# D_Time      datetime64[ns]
# DHT_RH             float64
# DHT_TEMP           float64
# AHT_RH             float64
# AHT_TEMP           float64
# SPS_PM1            float64
# SPS_PM25           float64
# SPS_PM4            float64
# SPS_PM10           float64
# dtype: object

# %%
df['month']=df['D_Time'].dt.month
df['day']=df['D_Time'].dt.day
df['time']=df['D_Time'].dt.time

# %%
df
# Out:
#        DF_PM1  DF_PM25  DF_PM10  P_Id name        lat  NSO        lon  EWO  \
# 0         NaN      NaN      NaN   NaN  NaN        NaN  NaN        NaN  NaN
# 1         NaN      NaN      NaN   NaN  NaN        NaN  NaN        NaN  NaN
# 2        10.0     14.0     18.0   NaN  NaN        NaN  NaN        NaN  NaN
# 3         9.0     12.0     13.0   NaN  NaN        NaN  NaN        NaN  NaN
# 4         9.0     13.0     15.0   NaN  NaN        NaN  NaN        NaN  NaN
# ...       ...      ...      ...   ...  ...        ...  ...        ...  ...
# 91892    22.0     31.0     41.0  57.0   M4  12.965772    N  80.203153    E
# 91893   111.0    145.0    174.0  58.0   M4  12.965793    N  80.202386    E
# 91894    70.0     87.0    105.0  59.0   M4  12.965595    N  80.201811    E
# 91895    15.0     23.0     32.0  60.0   M4  12.965311    N  80.201358    E
# 91896    14.0     18.0     26.0  61.0   M4  12.965468    N  80.200651    E
#
# ...

# %%
#removing P_Id column
df.drop(columns=['P_Id'],inplace=True)
df
# Out:
#        DF_PM1  DF_PM25  DF_PM10 name        lat  NSO        lon  EWO   Alt  \
# 0         NaN      NaN      NaN  NaN        NaN  NaN        NaN  NaN   NaN
# 1         NaN      NaN      NaN  NaN        NaN  NaN        NaN  NaN   NaN
# 2        10.0     14.0     18.0  NaN        NaN  NaN        NaN  NaN   NaN
# 3         9.0     12.0     13.0  NaN        NaN  NaN        NaN  NaN   NaN
# 4         9.0     13.0     15.0  NaN        NaN  NaN        NaN  NaN   NaN
# ...       ...      ...      ...  ...        ...  ...        ...  ...   ...
# 91892    22.0     31.0     41.0   M4  12.965772    N  80.203153    E   8.4
# 91893   111.0    145.0    174.0   M4  12.965793    N  80.202386    E  11.7
# 91894    70.0     87.0    105.0   M4  12.965595    N  80.201811    E  13.2
# 91895    15.0     23.0     32.0   M4  12.965311    N  80.201358    E  10.2
# 91896    14.0     18.0     26.0   M4  12.965468    N  80.200651    E   6.1
#
# ...

# %%
df.name.astype('str')
# Out:
# 0        nan
# 1        nan
# 2        nan
# 3        nan
# 4        nan
#         ...
# 91892     M4
# 91893     M4
# 91894     M4
# 91895     M4
# 91896     M4
# Name: name, Length: 91897, dtype: object

# %%
df.name.fillna('unknown',inplace=True)

# %%
df.name.unique()
# Out:
# array(['unknown', 'M5', 'S2', 'S8', 'S13', 'M1', 'S7', 'M3', 'S6', 'S17',
#        'M6', 'S11', 'S10', 'M7', 'S9', 'M4'], dtype=object)

# %%
df=df[df['name']!='unknown']
df
# Out:
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO   Alt  \
# 90       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 91       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 92       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 93       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 94       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# ...       ...      ...      ...  ...        ...  ..        ...  ..   ...
# 91892    22.0     31.0     41.0   M4  12.965772   N  80.203153   E   8.4
# 91893   111.0    145.0    174.0   M4  12.965793   N  80.202386   E  11.7
# 91894    70.0     87.0    105.0   M4  12.965595   N  80.201811   E  13.2
# 91895    15.0     23.0     32.0   M4  12.965311   N  80.201358   E  10.2
# 91896    14.0     18.0     26.0   M4  12.965468   N  80.200651   E   6.1
#
#          sog  ...  DHT_TEMP  AHT_RH  AHT_TEMP  SPS_PM1 SPS_PM25  SPS_PM4  \
# ...

# %%
names=df.name.unique()
names
# Out:
# array(['M5', 'S2', 'S8', 'S13', 'M1', 'S7', 'M3', 'S6', 'S17', 'M6',
#        'S11', 'S10', 'M7', 'S9', 'M4'], dtype=object)

# %% [markdown]
# table=pd.pivot_table(df,index=['name'],columns=['AHT_RH','AHT_TEMP',])

# %% [markdown]
# table

# %%
mobile=[]
stationary=[]
for name in names:
    if name.startswith('M'):
        mobile.append(name)
    else:
        stationary.append(name)

# %%
df.name.nunique()
# Out:
# 15

# %%
print(mobile)
print(stationary)
print(len(mobile)+len(stationary))
# Out:
# ['M5', 'M1', 'M3', 'M6', 'M7', 'M4']
# ['S2', 'S8', 'S13', 'S7', 'S6', 'S17', 'S11', 'S10', 'S9']
# 15

# %%
mobiledf=df.loc[df['name'].isin(mobile)]
stationarydf=df.loc[df['name'].isin(stationary)]

# %% [markdown]
# ### mobiledf

# %%
mobiledf
# Out:
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO   Alt  \
# 90       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 91       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 92       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 93       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 94       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# ...       ...      ...      ...  ...        ...  ..        ...  ..   ...
# 91892    22.0     31.0     41.0   M4  12.965772   N  80.203153   E   8.4
# 91893   111.0    145.0    174.0   M4  12.965793   N  80.202386   E  11.7
# 91894    70.0     87.0    105.0   M4  12.965595   N  80.201811   E  13.2
# 91895    15.0     23.0     32.0   M4  12.965311   N  80.201358   E  10.2
# 91896    14.0     18.0     26.0   M4  12.965468   N  80.200651   E   6.1
#
#          sog  ...  DHT_TEMP  AHT_RH  AHT_TEMP  SPS_PM1 SPS_PM25  SPS_PM4  \
# ...

# %% [markdown]
# ### stationary df

# %%
stationarydf
# Out:
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO  Alt   sog  \
# 8929     15.0     20.0     28.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8930     15.0     20.0     28.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8931     14.0     19.0     27.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8932     14.0     19.0     27.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8933     14.0     19.0     27.0   S2   0.000000   N   0.000000   E  0.0  0.00
# ...       ...      ...      ...  ...        ...  ..        ...  ..  ...   ...
# 84499    18.0     23.0     31.0   S9  12.991332   N  80.233410   E  6.4  0.43
# 84500    18.0     23.0     31.0   S9  12.991341   N  80.233414   E  6.1  0.17
# 84501    18.0     23.0     31.0   S9  12.991329   N  80.233393   E  2.1  0.65
# 84502    18.0     23.0     31.0   S9  12.991329   N  80.233393   E  2.1  0.65
# 84503    19.0     26.0     33.0   S9  12.991311   N  80.233415   E  6.0  0.07
#
# ...

# %% [markdown]
# ### dealing with stationary df

# %%
#percentage of null values
stationarydf.isnull().sum()/stationarydf.shape[0]
# Out:
# DF_PM1      0.000000
# DF_PM25     0.000000
# DF_PM10     0.000000
# name        0.000000
# lat         0.000000
# NSO         0.000000
# lon         0.000000
# EWO         0.000000
# Alt         0.000000
# sog         0.000000
# cog         0.000000
# hdop        0.000000
# vdop        0.000000
# pdop        0.000000
# D_Time      0.000000
# DHT_RH      0.248629
# DHT_TEMP    0.248629
# AHT_RH      0.608150
# AHT_TEMP    0.608150
# SPS_PM1     0.978082
# SPS_PM25    0.978082
# SPS_PM4     0.978082
# SPS_PM10    0.978082
# month       0.000000
# day         0.000000
# time        0.000000
# dtype: float64

# %%
#we can see that 97% of SPS PM4 are null values
stationarydf.drop(columns=['SPS_PM4'],inplace=True)
stationarydf
# Out:
# C:\Users\jbroh\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO  Alt   sog  \
# 8929     15.0     20.0     28.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8930     15.0     20.0     28.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8931     14.0     19.0     27.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8932     14.0     19.0     27.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8933     14.0     19.0     27.0   S2   0.000000   N   0.000000   E  0.0  0.00
# ...       ...      ...      ...  ...        ...  ..        ...  ..  ...   ...
# 84499    18.0     23.0     31.0   S9  12.991332   N  80.233410   E  6.4  0.43
# ...

# %% [markdown]
# stationarydf['lat'].nunique()

# %%
s=stationarydf.groupby('name')
sdict={}
for group_name in stationary:
    sdict[str(group_name)]=s.get_group(group_name)

# %%
sdict['S2'].columns
# Out:
# Index(['DF_PM1', 'DF_PM25', 'DF_PM10', 'name', 'lat', 'NSO', 'lon', 'EWO',
#        'Alt', 'sog', 'cog', 'hdop', 'vdop', 'pdop', 'D_Time', 'DHT_RH',
#        'DHT_TEMP', 'AHT_RH', 'AHT_TEMP', 'SPS_PM1', 'SPS_PM25', 'SPS_PM10',
#        'month', 'day', 'time'],
#       dtype='object')

# %%
for key in sdict.keys():
    print(key)
    print((sdict[key][["AHT_RH","DHT_RH","AHT_TEMP","DHT_TEMP"]].isnull().sum())/sdict[key].shape[0])
    print('_________________')
# Out:
# S2
# AHT_RH      0.0
# DHT_RH      1.0
# AHT_TEMP    0.0
# DHT_TEMP    1.0
# dtype: float64
# _________________
# S8
# AHT_RH      1.0
# DHT_RH      0.0
# AHT_TEMP    1.0
# DHT_TEMP    0.0
# dtype: float64
# _________________
# S13
# AHT_RH      1.0
# DHT_RH      0.0
# AHT_TEMP    1.0
# DHT_TEMP    0.0
# dtype: float64
# _________________
# S7
# AHT_RH      1.0
# DHT_RH      0.0
# AHT_TEMP    1.0
# DHT_TEMP    0.0
# dtype: float64
# _________________
# S6
# AHT_RH      1.0
# DHT_RH      0.0
# AHT_TEMP    1.0
# DHT_TEMP    0.0
# dtype: float64
# _________________
# S17
# AHT_RH      0.0
# DHT_RH      1.0
# AHT_TEMP    0.0
# DHT_TEMP    1.0
# dtype: float64
# _________________
# S11
# AHT_RH      1.0
# DHT_RH      0.0
# AHT_TEMP    1.0
# DHT_TEMP    0.0
# dtype: float64
# _________________
# S10
# AHT_RH      0.0
# DHT_RH      0.0
# AHT_TEMP    0.0
# DHT_TEMP    0.0
# dtype: float64
# _________________
# S9
# AHT_RH      0.0
# DHT_RH      0.0
# AHT_TEMP    0.0
# DHT_TEMP    0.0
# ...

# %%
#for s9 and s10 sensors comparing the RH and Temp by two sensors


plt.figure(figsize=(12,12))
plt.plot(sdict['S9']['AHT_TEMP'],sdict['S9']['DHT_TEMP'],'b.')
plt.title('AHT_TEMP vs DHT_TEMP')
plt.xlabel('AHT_TEMP')
plt.ylabel('DHT_TEMP')
plt.show()


plt.figure(figsize=(12,12))
plt.plot(sdict['S9']['AHT_RH'],sdict['S9']['DHT_RH'],'b.')
plt.title('AHT_RH vs DHT_RH')
plt.xlabel('AHT_RH')
plt.ylabel('DHT_RH')
plt.show()

# %%
plt.figure(figsize=(12,12))
plt.plot(sdict['S10']['AHT_TEMP'],sdict['S10']['DHT_TEMP'],'b.')
plt.title('AHT_TEMP vs DHT_TEMP')
plt.xlabel('AHT_TEMP')
plt.ylabel('DHT_TEMP')
plt.show()


plt.figure(figsize=(12,12))
plt.plot(sdict['S10']['AHT_RH'],sdict['S10']['DHT_RH'],'b.')
plt.title('AHT_RH vs DHT_RH')
plt.xlabel('AHT_RH')
plt.ylabel('DHT_RH')
plt.show()

# %%
for key in sdict.keys():
    aht_rh=(sdict[key][["AHT_RH","DHT_RH","AHT_TEMP","DHT_TEMP"]].isnull().sum()/sdict[key].shape[0]).values[0]
    dht_rh=(sdict[key][["AHT_RH","DHT_RH","AHT_TEMP","DHT_TEMP"]].isnull().sum()/sdict[key].shape[0]).values[1]
    aht_temp=(sdict[key][["AHT_RH","DHT_RH","AHT_TEMP","DHT_TEMP"]].isnull().sum()/sdict[key].shape[0]).values[2]
    dht_temp=(sdict[key][["AHT_RH","DHT_RH","AHT_TEMP","DHT_TEMP"]].isnull().sum()/sdict[key].shape[0]).values[3]
    if (aht_rh==1 and dht_rh==0):
        sdict[key]['RH']=sdict[key]["DHT_RH"]
    elif (aht_rh==0 and dht_rh==1):
        sdict[key]['RH']=sdict[key]["AHT_RH"]
    else:
        sdict[key]['RH']=(sdict[key]["AHT_RH"]+sdict[key]['DHT_RH'])/2
    if (aht_temp==1 and dht_temp==0):
        sdict[key]['TEMP']=sdict[key]["DHT_TEMP"]
    elif (aht_temp==0 and dht_temp==1):
        sdict[key]['TEMP']=sdict[key]["AHT_TEMP"]
    else:
        sdict[key]['TEMP']=(sdict[key]["AHT_TEMP"]+sdict[key]['DHT_TEMP'])/2
    
    print(key)
    print(sdict[key])
    print("_____________________________________________________________________________")
# Out:
# <ipython-input-31-24761d50f00a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdict[key]['RH']=sdict[key]["AHT_RH"]
# <ipython-input-31-24761d50f00a>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdict[key]['TEMP']=sdict[key]["AHT_TEMP"]
# <ipython-input-31-24761d50f00a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
for key,values in zip(sdict.keys(),sdict.values()):
    print(key)
    print(values.isnull().sum()/values.shape[0])
    
    print('_______________')
# Out:
# S2
# DF_PM1      0.0
# DF_PM25     0.0
# DF_PM10     0.0
# name        0.0
# lat         0.0
# NSO         0.0
# lon         0.0
# EWO         0.0
# Alt         0.0
# sog         0.0
# cog         0.0
# hdop        0.0
# vdop        0.0
# pdop        0.0
# D_Time      0.0
# DHT_RH      1.0
# DHT_TEMP    1.0
# AHT_RH      0.0
# AHT_TEMP    0.0
# SPS_PM1     1.0
# SPS_PM25    1.0
# SPS_PM10    1.0
# month       0.0
# day         0.0
# time        0.0
# RH          0.0
# TEMP        0.0
# dtype: float64
# _______________
# S8
# DF_PM1      0.0
# DF_PM25     0.0
# DF_PM10     0.0
# name        0.0
# lat         0.0
# NSO         0.0
# lon         0.0
# EWO         0.0
# Alt         0.0
# sog         0.0
# cog         0.0
# hdop        0.0
# vdop        0.0
# pdop        0.0
# D_Time      0.0
# DHT_RH      0.0
# DHT_TEMP    0.0
# AHT_RH      1.0
# AHT_TEMP    1.0
# SPS_PM1     1.0
# SPS_PM25    1.0
# SPS_PM10    1.0
# month       0.0
# day         0.0
# time        0.0
# RH          0.0
# ...

# %%
for key in sdict.keys():
    print(key)
    print((sdict[key][['DF_PM1','SPS_PM1','DF_PM25','SPS_PM25','DF_PM10','SPS_PM10']].isnull().sum())/sdict[key].shape[0])
    print('_________________')
# Out:
# S2
# DF_PM1      0.0
# SPS_PM1     1.0
# DF_PM25     0.0
# SPS_PM25    1.0
# DF_PM10     0.0
# SPS_PM10    1.0
# dtype: float64
# _________________
# S8
# DF_PM1      0.0
# SPS_PM1     1.0
# DF_PM25     0.0
# SPS_PM25    1.0
# DF_PM10     0.0
# SPS_PM10    1.0
# dtype: float64
# _________________
# S13
# DF_PM1      0.0
# SPS_PM1     1.0
# DF_PM25     0.0
# SPS_PM25    1.0
# DF_PM10     0.0
# SPS_PM10    1.0
# dtype: float64
# _________________
# S7
# DF_PM1      0.0
# SPS_PM1     1.0
# DF_PM25     0.0
# SPS_PM25    1.0
# DF_PM10     0.0
# SPS_PM10    1.0
# dtype: float64
# _________________
# S6
# DF_PM1      0.0
# SPS_PM1     1.0
# DF_PM25     0.0
# SPS_PM25    1.0
# DF_PM10     0.0
# SPS_PM10    1.0
# dtype: float64
# _________________
# S17
# DF_PM1      0.0
# SPS_PM1     1.0
# DF_PM25     0.0
# SPS_PM25    1.0
# DF_PM10     0.0
# SPS_PM10    1.0
# dtype: float64
# _________________
# S11
# DF_PM1      0.0
# SPS_PM1     1.0
# DF_PM25     0.0
# SPS_PM25    1.0
# DF_PM10     0.0
# ...

# %%
for key in sdict.keys():
    plt.title(str(key)+' DF vs SPS sensor')
    plt.ylabel('% of null values')
    plt.plot(['DF_PM1','SPS_PM1','DF_PM25','SPS_PM25','DF_PM10','SPS_PM10'],((sdict[key][['DF_PM1','SPS_PM1','DF_PM25','SPS_PM25','DF_PM10','SPS_PM10']].isnull().sum())/sdict[key].shape[0])*100,'g*')
    plt.show()

# %%
# we can compare the SPS and DF sensors of S10 sensor
plt.title('PM1 sensors')
plt.xlabel('DF_PM1')
plt.ylabel('SPS_PM1')
plt.plot(sdict['S10']['DF_PM1'],'b.')
plt.plot(sdict['S10']['SPS_PM1'],'g.')
plt.show()

plt.title('PM25 sensors')
plt.xlabel('DF_PM25')
plt.ylabel('SPS_PM25')
plt.plot(sdict['S10']['DF_PM25'],sdict['S10']['SPS_PM25'],'g.')
plt.show()

plt.title('PM10  sensors')
plt.xlabel('DF_PM10')
plt.ylabel('SPS_PM10')
plt.plot(sdict['S10']['DF_PM10'],sdict['S10']['SPS_PM10'],"r.")
plt.show()

# %%
stationarydf.columns
# Out:
# Index(['DF_PM1', 'DF_PM25', 'DF_PM10', 'name', 'lat', 'NSO', 'lon', 'EWO',
#        'Alt', 'sog', 'cog', 'hdop', 'vdop', 'pdop', 'D_Time', 'DHT_RH',
#        'DHT_TEMP', 'AHT_RH', 'AHT_TEMP', 'SPS_PM1', 'SPS_PM25', 'SPS_PM10',
#        'month', 'day', 'time'],
#       dtype='object')

# %% [markdown]
# ### mobile df

# %%
mobiledf
# Out:
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO   Alt  \
# 90       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 91       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 92       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 93       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 94       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# ...       ...      ...      ...  ...        ...  ..        ...  ..   ...
# 91892    22.0     31.0     41.0   M4  12.965772   N  80.203153   E   8.4
# 91893   111.0    145.0    174.0   M4  12.965793   N  80.202386   E  11.7
# 91894    70.0     87.0    105.0   M4  12.965595   N  80.201811   E  13.2
# 91895    15.0     23.0     32.0   M4  12.965311   N  80.201358   E  10.2
# 91896    14.0     18.0     26.0   M4  12.965468   N  80.200651   E   6.1
#
#          sog  ...  DHT_TEMP  AHT_RH  AHT_TEMP  SPS_PM1 SPS_PM25  SPS_PM4  \
# ...

# %%
mobiledf.isnull().sum()/mobiledf.shape[0]
# Out:
# DF_PM1      0.000156
# DF_PM25     0.000156
# DF_PM10     0.000156
# name        0.000000
# lat         0.000000
# NSO         0.000000
# lon         0.000000
# EWO         0.000000
# Alt         0.000000
# sog         0.000000
# cog         0.000000
# hdop        0.000000
# vdop        0.000000
# pdop        0.000000
# D_Time      0.000000
# DHT_RH      0.223510
# DHT_TEMP    0.223510
# AHT_RH      0.554309
# AHT_TEMP    0.554309
# SPS_PM1     0.811790
# SPS_PM25    0.811790
# SPS_PM4     0.811790
# SPS_PM10    0.811790
# month       0.000000
# day         0.000000
# time        0.000000
# dtype: float64

# %%
m=mobiledf.groupby('name')
mdict={}

for group_name in mobile:
    mdict[str(group_name)]=m.get_group(group_name)

# %%
mdict['M5']
# Out:
#       DF_PM1  DF_PM25  DF_PM10 name  lat NSO  lon EWO  Alt  sog  ...  \
# 90      12.0     16.0     23.0   M5  0.0   N  0.0   E  0.0  0.0  ...
# 91      12.0     16.0     23.0   M5  0.0   N  0.0   E  0.0  0.0  ...
# 92      12.0     16.0     22.0   M5  0.0   N  0.0   E  0.0  0.0  ...
# 93      12.0     16.0     22.0   M5  0.0   N  0.0   E  0.0  0.0  ...
# 94      12.0     16.0     22.0   M5  0.0   N  0.0   E  0.0  0.0  ...
# ...      ...      ...      ...  ...  ...  ..  ...  ..  ...  ...  ...
# 8924    10.0     15.0     19.0   M5  0.0   N  0.0   E  0.0  0.0  ...
# 8925     9.0     13.0     19.0   M5  0.0   N  0.0   E  0.0  0.0  ...
# 8926     9.0     13.0     19.0   M5  0.0   N  0.0   E  0.0  0.0  ...
# 8927     8.0     12.0     17.0   M5  0.0   N  0.0   E  0.0  0.0  ...
# 8928     7.0     11.0     16.0   M5  0.0   N  0.0   E  0.0  0.0  ...
#
#       DHT_TEMP  AHT_RH  AHT_TEMP  SPS_PM1 SPS_PM25  SPS_PM4  SPS_PM10  month  \
# ...

# %%
mobile
# Out:
# ['M5', 'M1', 'M3', 'M6', 'M7', 'M4']

# %%
for key in mdict.keys():
    print(key)
    print((mdict[key][['lat','lon']].isnull().sum()/mdict[key].shape[0])*100)
    print('--------------------------')
# Out:
# M5
# lat    0.0
# lon    0.0
# dtype: float64
# --------------------------
# M1
# lat    0.0
# lon    0.0
# dtype: float64
# --------------------------
# M3
# lat    0.0
# lon    0.0
# dtype: float64
# --------------------------
# M6
# lat    0.0
# lon    0.0
# dtype: float64
# --------------------------
# M7
# lat    0.0
# lon    0.0
# dtype: float64
# --------------------------
# M4
# lat    0.0
# lon    0.0
# dtype: float64
# --------------------------

# %%
plt.plot(mdict['M5']['lon'],mdict['M5']['lat'],'g*')

# %%
for key in mdict.keys():
    plt.title(str(key)+ " position graph")
    plt.xlabel('latitude')
    plt.ylabel('longitude')
    plt.plot(mdict[key]['lat'],mdict[key]['lon'],'g.')
    plt.show()

# %%
mdict['M5'].columns
# Out:
# Index(['DF_PM1', 'DF_PM25', 'DF_PM10', 'name', 'lat', 'NSO', 'lon', 'EWO',
#        'Alt', 'sog', 'cog', 'hdop', 'vdop', 'pdop', 'D_Time', 'DHT_RH',
#        'DHT_TEMP', 'AHT_RH', 'AHT_TEMP', 'SPS_PM1', 'SPS_PM25', 'SPS_PM4',
#        'SPS_PM10', 'month', 'day', 'time'],
#       dtype='object')

# %%
for key in mdict.keys():
    print(key)
    print((mdict[key][['DHT_TEMP','AHT_TEMP','DHT_RH','AHT_RH']].isnull().sum()/mdict[key].shape[0])*100)
    print('------------------')
# Out:
# M5
# DHT_TEMP      0.0
# AHT_TEMP    100.0
# DHT_RH        0.0
# AHT_RH      100.0
# dtype: float64
# ------------------
# M1
# DHT_TEMP    50.25444
# AHT_TEMP     0.00000
# DHT_RH      50.25444
# AHT_RH       0.00000
# dtype: float64
# ------------------
# M3
# DHT_TEMP      0.0
# AHT_TEMP    100.0
# DHT_RH        0.0
# AHT_RH      100.0
# dtype: float64
# ------------------
# M6
# DHT_TEMP      0.0
# AHT_TEMP    100.0
# DHT_RH        0.0
# AHT_RH      100.0
# dtype: float64
# ------------------
# M7
# DHT_TEMP    50.072117
# AHT_TEMP     0.000000
# DHT_RH      50.072117
# AHT_RH       0.000000
# dtype: float64
# ------------------
# M4
# DHT_TEMP      0.0
# AHT_TEMP    100.0
# DHT_RH        0.0
# AHT_RH      100.0
# dtype: float64
# ------------------

# %%
for key in mdict.keys():
    plt.title(key)
    plt.ylim(-1,101)
    plt.plot(['DHT_TEMP','AHT_TEMP','DHT_RH','AHT_RH'],(mdict[key][['DHT_TEMP','AHT_TEMP','DHT_RH','AHT_RH']].isnull().sum()/mdict[key].shape[0])*100,'g*')
    
    plt.show()

# %%
mobiledf.columns
# Out:
# Index(['DF_PM1', 'DF_PM25', 'DF_PM10', 'name', 'lat', 'NSO', 'lon', 'EWO',
#        'Alt', 'sog', 'cog', 'hdop', 'vdop', 'pdop', 'D_Time', 'DHT_RH',
#        'DHT_TEMP', 'AHT_RH', 'AHT_TEMP', 'SPS_PM1', 'SPS_PM25', 'SPS_PM4',
#        'SPS_PM10', 'month', 'day', 'time'],
#       dtype='object')

# %%
for key in mdict.keys():
    print(key)
    print((mdict[key][['DF_PM1','DF_PM25','DF_PM10','SPS_PM1','SPS_PM25','SPS_PM4','SPS_PM10']].isnull().sum()/mdict[key].shape[0])*100)
    print('------------------')
# Out:
# M5
# DF_PM1        0.0
# DF_PM25       0.0
# DF_PM10       0.0
# SPS_PM1     100.0
# SPS_PM25    100.0
# SPS_PM4     100.0
# SPS_PM10    100.0
# dtype: float64
# ------------------
# M1
# DF_PM1      0.083082
# DF_PM25     0.083082
# DF_PM10     0.083082
# SPS_PM1     0.000000
# SPS_PM25    0.000000
# SPS_PM4     0.000000
# SPS_PM10    0.000000
# dtype: float64
# ------------------
# M3
# DF_PM1        0.0
# DF_PM25       0.0
# DF_PM10       0.0
# SPS_PM1     100.0
# SPS_PM25    100.0
# SPS_PM4     100.0
# SPS_PM10    100.0
# dtype: float64
# ------------------
# M6
# DF_PM1        0.0
# DF_PM25       0.0
# DF_PM10       0.0
# SPS_PM1     100.0
# SPS_PM25    100.0
# SPS_PM4     100.0
# SPS_PM10    100.0
# dtype: float64
# ------------------
# M7
# DF_PM1        0.0
# DF_PM25       0.0
# DF_PM10       0.0
# SPS_PM1     100.0
# SPS_PM25    100.0
# SPS_PM4     100.0
# SPS_PM10    100.0
# dtype: float64
# ------------------
# M4
# DF_PM1        0.0
# DF_PM25       0.0
# ...

# %%
for key in mdict.keys():
    plt.title(key)
    plt.ylim(-1,101)
    plt.plot(['DF_PM1','DF_PM25','DF_PM10','SPS_PM1','SPS_PM25','SPS_PM4','SPS_PM10'],(mdict[key][['DF_PM1','DF_PM25','DF_PM10','SPS_PM1','SPS_PM25','SPS_PM4','SPS_PM10']].isnull().sum()/mdict[key].shape[0])*100,'g*')
    
    plt.show()

# %%
plt.xlabel('DF_PM1')
plt.ylabel('SPS_PM1')
plt.plot(mdict['M1']['DF_PM1'],mdict['M1']['SPS_PM1'],'g*')
plt.show()

plt.xlabel('DF_PM25')
plt.ylabel('SPS_PM25')
plt.plot(mdict['M1']['DF_PM25'],mdict['M1']['SPS_PM25'],'b.')
plt.show()

plt.xlabel('DF_PM10')
plt.ylabel('SPS_PM10')
plt.plot(mdict['M1']['DF_PM10'],mdict['M1']['SPS_PM10'],'r+')
plt.show()

# %%
#drooping the SPS sensor values
mobiledf.drop(columns=['SPS_PM1','SPS_PM25','SPS_PM4','SPS_PM10'],inplace=True)
mobiledf
# Out:
# C:\Users\jbroh\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO   Alt  \
# 90       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 91       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 92       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 93       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 94       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# ...       ...      ...      ...  ...        ...  ..        ...  ..   ...
# 91892    22.0     31.0     41.0   M4  12.965772   N  80.203153   E   8.4
# ...

# %%
mobiledf.fillna(value={'DHT_TEMP':0,'AHT_TEMP':0,'DHT_RH':0,'AHT_RH':0},inplace=True)
mobiledf
# Out:
# C:\Users\jbroh\anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO   Alt  \
# 90       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 91       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 92       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 93       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 94       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# ...       ...      ...      ...  ...        ...  ..        ...  ..   ...
# 91892    22.0     31.0     41.0   M4  12.965772   N  80.203153   E   8.4
# ...

# %%
mobiledf['Temp']=mobiledf[['AHT_TEMP','DHT_TEMP']].max(axis=1)
mobiledf['Rh']=mobiledf[['AHT_RH','DHT_RH']].max(axis=1)
mobiledf
# Out:
# <ipython-input-56-db204ebba0dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mobiledf['Temp']=mobiledf[['AHT_TEMP','DHT_TEMP']].max(axis=1)
# <ipython-input-56-db204ebba0dc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mobiledf['Rh']=mobiledf[['AHT_RH','DHT_RH']].max(axis=1)
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO   Alt  \
# 90       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# ...

# %%
mobiledf[['Temp','Rh']].isnull().sum()
# Out:
# Temp    0
# Rh      0
# dtype: int64

# %%
#dropping AHT_temp,DHT_temp,AHT_RH,DHT_RH
mobiledf.drop(columns=['DHT_RH','DHT_TEMP','AHT_TEMP','AHT_RH'],inplace=True)
mobiledf
# Out:
# C:\Users\jbroh\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO   Alt  \
# 90       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 91       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 92       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 93       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 94       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# ...       ...      ...      ...  ...        ...  ..        ...  ..   ...
# 91892    22.0     31.0     41.0   M4  12.965772   N  80.203153   E   8.4
# ...

# %%
mobiledf.describe()
# Out:
#              DF_PM1       DF_PM25       DF_PM10           lat           lon  \
# count  51153.000000  51153.000000  51153.000000  51161.000000  51161.000000
# mean      17.846969     23.134342     29.149063      7.346306     45.269481
# std       27.833349     36.600219     41.897361      6.456937     39.783096
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        8.000000     11.000000     14.000000      0.000000      0.000000
# 50%       13.000000     18.000000     22.000000     12.981334     80.208300
# 75%       21.000000     28.000000     32.000000     13.025992     80.230965
# max     1200.000000   1200.000000   1200.000000     43.250000     80.292625
#
#                 Alt           sog           cog          hdop          vdop  \
# count  51161.000000  51161.000000  51161.000000  51161.000000  51161.000000
# mean       5.375562      7.470440     88.229453     46.761184     47.431161
# ...

# %%
sns.histplot(mobiledf['Temp'])
# Out:
# <AxesSubplot:xlabel='Temp', ylabel='Count'>

# %%
#removing the temp>100
mobiledf=mobiledf[mobiledf['Temp']<100]

# %%
sns.histplot(mobiledf['Temp'])
# Out:
# <AxesSubplot:xlabel='Temp', ylabel='Count'>

# %%
mobiledf=mobiledf[mobiledf['Temp']>10]
sns.histplot(mobiledf['Temp'],kde=True)
# Out:
# <AxesSubplot:xlabel='Temp', ylabel='Count'>

# %%
mobiledf
# Out:
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO   Alt  \
# 90       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 91       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 92       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 93       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 94       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# ...       ...      ...      ...  ...        ...  ..        ...  ..   ...
# 91892    22.0     31.0     41.0   M4  12.965772   N  80.203153   E   8.4
# 91893   111.0    145.0    174.0   M4  12.965793   N  80.202386   E  11.7
# 91894    70.0     87.0    105.0   M4  12.965595   N  80.201811   E  13.2
# 91895    15.0     23.0     32.0   M4  12.965311   N  80.201358   E  10.2
# 91896    14.0     18.0     26.0   M4  12.965468   N  80.200651   E   6.1
#
#          sog     cog   hdop   vdop   pdop              D_Time  month   day  \
# ...

# %%
sns.histplot(mobiledf['Rh'])
# Out:
# <AxesSubplot:xlabel='Rh', ylabel='Count'>

# %%
mobiledf=mobiledf[mobiledf['Rh']<80]
sns.histplot(mobiledf['Rh'],kde=True)
# Out:
# <AxesSubplot:xlabel='Rh', ylabel='Count'>

# %%
mobiledf
# Out:
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO   Alt  \
# 90       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 91       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 92       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 93       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 94       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# ...       ...      ...      ...  ...        ...  ..        ...  ..   ...
# 91892    22.0     31.0     41.0   M4  12.965772   N  80.203153   E   8.4
# 91893   111.0    145.0    174.0   M4  12.965793   N  80.202386   E  11.7
# 91894    70.0     87.0    105.0   M4  12.965595   N  80.201811   E  13.2
# 91895    15.0     23.0     32.0   M4  12.965311   N  80.201358   E  10.2
# 91896    14.0     18.0     26.0   M4  12.965468   N  80.200651   E   6.1
#
#          sog     cog   hdop   vdop   pdop              D_Time  month   day  \
# ...

# %%
mobiledf.isnull().sum()/mobiledf.shape[0]
# Out:
# DF_PM1     0.000221
# DF_PM25    0.000221
# DF_PM10    0.000221
# name       0.000000
# lat        0.000000
# NSO        0.000000
# lon        0.000000
# EWO        0.000000
# Alt        0.000000
# sog        0.000000
# cog        0.000000
# hdop       0.000000
# vdop       0.000000
# pdop       0.000000
# D_Time     0.000000
# month      0.000000
# day        0.000000
# time       0.000000
# Temp       0.000000
# Rh         0.000000
# dtype: float64

# %%
mobiledf.dropna(how='any',axis=0,inplace=True)
mobiledf
# Out:
# <ipython-input-72-269e1bcd62ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mobiledf.dropna(how='any',axis=0,inplace=True)
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO   Alt  \
# 90       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 91       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 92       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 93       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 94       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# ...       ...      ...      ...  ...        ...  ..        ...  ..   ...
# 91892    22.0     31.0     41.0   M4  12.965772   N  80.203153   E   8.4
# ...

# %%
mobiledf.isnull().sum()/mobiledf.shape[0]
# Out:
# DF_PM1     0.0
# DF_PM25    0.0
# DF_PM10    0.0
# name       0.0
# lat        0.0
# NSO        0.0
# lon        0.0
# EWO        0.0
# Alt        0.0
# sog        0.0
# cog        0.0
# hdop       0.0
# vdop       0.0
# pdop       0.0
# D_Time     0.0
# month      0.0
# day        0.0
# time       0.0
# Temp       0.0
# Rh         0.0
# dtype: float64

# %%
mobiledf.groupby('day').mean()
# Out:
#          DF_PM1    DF_PM25    DF_PM10        lat        lon        Alt  \
# day
# 25.0  13.401405  16.574879  20.040843   2.787944  17.150424   3.577602
# 26.0  10.032956  13.338301  16.258633   1.388593   8.576037  -0.743645
# 27.0   7.922110  10.969391  14.087182   9.342107  57.657058   9.559511
# 28.0  25.422260  33.258949  43.161298  10.874607  66.969777  10.043456
# 29.0  15.792285  21.318991  28.325562  10.630224  65.508945   6.305914
# 30.0  19.468222  25.768087  33.692698  10.570887  65.226527   6.339875
#
#             sog         cog       hdop       vdop       pdop  month  \
# day
# 25.0   0.159653   29.710540  78.856430  79.066249  79.134282    5.0
# 26.0   0.242738    0.000000  99.827636  99.826270  99.832240    5.0
# 27.0   4.964529   89.671279  29.025056  30.016163  30.341632    5.0
# 28.0  10.656255  125.368465  19.808073  20.543849  20.938372    5.0
# 29.0  13.858501  128.445102  22.466003  24.080875  24.821437    5.0
# ...

# %%
mobiledf.groupby('day').min()
# Out:
#       DF_PM1  DF_PM25  DF_PM10 name  lat NSO  lon EWO    Alt  sog   cog  hdop  \
# day
# 25.0     0.0      0.0      0.0   M1  0.0   N  0.0   E  -34.2  0.0   0.0  0.88
# 26.0     1.0      2.0      3.0   M1  0.0   N  0.0   E  -11.2  0.0   0.0  3.10
# 27.0     0.0      0.0      0.0   M1  0.0   N  0.0   E  -60.6  0.0 -87.1  0.69
# 28.0     0.0      0.0      0.0   M1  0.0   N  0.0   E -133.3  0.0   0.0  0.73
# 29.0     0.0      1.0      1.0   M1  0.0   N  0.0   E -121.3  0.0   0.0  0.76
# 30.0     1.0      4.0      6.0   M1  0.0   N  0.0   E -162.6  0.0   0.0  0.77
#
#       vdop  pdop              D_Time  month      time   Temp     Rh
# day
# 25.0  1.39  1.71 2022-05-25 18:29:41    5.0  18:29:41  34.60  48.00
# 26.0  1.00  6.34 2022-05-26 02:04:48    5.0  02:04:48  28.20  33.14
# 27.0  1.00  1.35 2022-05-27 00:00:12    5.0  00:00:12  29.90  32.75
# 28.0  0.99  1.24 2022-05-28 01:36:32    5.0  01:36:32  27.30  20.70
# 29.0  0.95  1.45 2022-05-29 03:38:14    5.0  03:38:14  29.21  26.84
# ...

# %%
(mobiledf.groupby('day').max())['Temp']
# Out:
# day
# 25.0    37.88
# 26.0    40.54
# 27.0    40.73
# 28.0    57.50
# 29.0    47.40
# 30.0    48.30
# Name: Temp, dtype: float64

# %%
sns.histplot(mobiledf['Temp'])
# Out:
# <AxesSubplot:xlabel='Temp', ylabel='Count'>

# %%
sns.histplot(mobiledf['Temp'])
# Out:
# <AxesSubplot:xlabel='Temp', ylabel='Count'>

# %%
mobiledf.loc[mobiledf['Temp']>45,'Temp']=mobiledf['Temp'].mean()
mobiledf['Temp']
# Out:
# C:\Users\jbroh\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# 90       28.2
# 91       28.3
# 92       28.3
# 93       28.4
# 94       28.4
#          ...
# 91892    32.5
# 91893    32.4
# 91894    32.4
# 91895    32.4
# 91896    32.4
# Name: Temp, Length: 36148, dtype: float64

# %%
sns.histplot(mobiledf['Temp'])
# Out:
# <AxesSubplot:xlabel='Temp', ylabel='Count'>

# %%
mobiledf['Rh']
# Out:
# 90       56.9
# 91       57.1
# 92       56.9
# 93       56.9
# 94       56.9
#          ...
# 91892    72.1
# 91893    72.5
# 91894    72.5
# 91895    72.5
# 91896    72.5
# Name: Rh, Length: 36148, dtype: float64

# %%
sns.histplot(mobiledf['Rh'])
# Out:
# <AxesSubplot:xlabel='Rh', ylabel='Count'>

# %%
mobiledf
# Out:
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO   Alt  \
# 90       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 91       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 92       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 93       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 94       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# ...       ...      ...      ...  ...        ...  ..        ...  ..   ...
# 91892    22.0     31.0     41.0   M4  12.965772   N  80.203153   E   8.4
# 91893   111.0    145.0    174.0   M4  12.965793   N  80.202386   E  11.7
# 91894    70.0     87.0    105.0   M4  12.965595   N  80.201811   E  13.2
# 91895    15.0     23.0     32.0   M4  12.965311   N  80.201358   E  10.2
# 91896    14.0     18.0     26.0   M4  12.965468   N  80.200651   E   6.1
#
#          sog     cog   hdop   vdop   pdop              D_Time  month   day  \
# ...

# %%
plt.ylabel('Temperature')
plt.ylim(-1,50)
sns.barplot(x=mobiledf.groupby('day').mean()['Temp'].index,y=mobiledf.groupby('day').mean()['Temp'].values)
plt.show()

plt.ylabel('Max Temperature')
plt.ylim(-1,50)
sns.barplot(x=mobiledf.groupby('day').max()['Temp'].index,y=mobiledf.groupby('day').max()['Temp'].values)
plt.show()

plt.ylabel('Temperature')
plt.ylim(-1,50)
sns.barplot(x=mobiledf.groupby('day').min()['Temp'].index,y=mobiledf.groupby('day').min()['Temp'].values)
plt.show()

# %%
plt.ylabel('RH')
plt.ylim(-1,90)
sns.barplot(x=mobiledf.groupby('day').mean()['Rh'].index,y=mobiledf.groupby('day').mean()['Rh'].values)
plt.show()

plt.ylabel('Max RH')
plt.ylim(-1,90)
sns.barplot(x=mobiledf.groupby('day').max()['Rh'].index,y=mobiledf.groupby('day').max()['Rh'].values)
plt.show()

plt.ylabel('Min RH')
plt.ylim(-1,90)
sns.barplot(x=mobiledf.groupby('day').min()['Rh'].index,y=mobiledf.groupby('day').min()['Rh'].values)
plt.show()

# %%
mobiledf
# Out:
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO   Alt  \
# 90       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 91       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 92       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 93       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 94       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# ...       ...      ...      ...  ...        ...  ..        ...  ..   ...
# 91892    22.0     31.0     41.0   M4  12.965772   N  80.203153   E   8.4
# 91893   111.0    145.0    174.0   M4  12.965793   N  80.202386   E  11.7
# 91894    70.0     87.0    105.0   M4  12.965595   N  80.201811   E  13.2
# 91895    15.0     23.0     32.0   M4  12.965311   N  80.201358   E  10.2
# 91896    14.0     18.0     26.0   M4  12.965468   N  80.200651   E   6.1
#
#          sog     cog   hdop   vdop   pdop              D_Time  month   day  \
# ...

# %%
mobiledf.dtypes
# Out:
# DF_PM1            float64
# DF_PM25           float64
# DF_PM10           float64
# name               object
# lat               float64
# NSO                object
# lon               float64
# EWO                object
# Alt               float64
# sog               float64
# cog               float64
# hdop              float64
# vdop              float64
# pdop              float64
# D_Time     datetime64[ns]
# month             float64
# day               float64
# time               object
# Temp              float64
# Rh                float64
# dtype: object

# %%
mobiledf['hr']=mobiledf['D_Time'].dt.hour
# Out:
# <ipython-input-182-3c01f6ba4f1b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mobiledf['hr']=mobiledf['D_Time'].dt.hour

# %%
mobiledf
# Out:
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO   Alt  \
# 90       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 91       12.0     16.0     23.0   M5   0.000000   N   0.000000   E   0.0
# 92       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 93       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# 94       12.0     16.0     22.0   M5   0.000000   N   0.000000   E   0.0
# ...       ...      ...      ...  ...        ...  ..        ...  ..   ...
# 91892    22.0     31.0     41.0   M4  12.965772   N  80.203153   E   8.4
# 91893   111.0    145.0    174.0   M4  12.965793   N  80.202386   E  11.7
# 91894    70.0     87.0    105.0   M4  12.965595   N  80.201811   E  13.2
# 91895    15.0     23.0     32.0   M4  12.965311   N  80.201358   E  10.2
# 91896    14.0     18.0     26.0   M4  12.965468   N  80.200651   E   6.1
#
#          sog  ...   hdop   vdop   pdop              D_Time month   day  \
# ...

# %%
mobiledf.groupby(['day','hr']).mean()
# Out:
#             DF_PM1    DF_PM25    DF_PM10        lat        lon        Alt  \
# day  hr
# 25.0 18  14.875472  19.075472  24.498113   4.476244  27.536222   6.843019
#      19  14.659274  18.752016  23.375000   3.915819  24.088699   5.993145
#      20   9.745731  11.749526  13.982922   4.476995  27.540831   3.401518
#      21  12.602906  15.123487  17.644068   2.083100  12.814537   3.795642
#      22  15.101156  18.141618  21.141618   0.000000   0.000000   0.000000
# ...            ...        ...        ...        ...        ...        ...
# 30.0 12  12.127072  16.232044  19.900552   6.818389  42.110102   3.024309
#      13  17.461538  23.444139  30.619963  12.013761  74.360632  10.218407
#      14  10.454148  14.395197  19.707424  12.908814  80.239236   5.588428
#      15   9.509728  13.377432  18.091440  12.935536  80.233005  10.660117
#      16  25.185185  33.259259  44.518519  12.970372  80.214243   8.327778
#
# ...

# %%
mobiledf.groupby(['day','hr']).mean()['Temp']
# Out:
# day   hr
# 25.0  18    35.766943
#       19    35.459456
#       20    35.368729
#       21    35.071550
#       22    34.868208
#               ...
# 30.0  12    34.475193
#       13    34.279936
#       14    34.654127
#       15    33.762957
#       16    32.575926
# Name: Temp, Length: 85, dtype: float64

# %%
mobiledf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()
# Out:
#      day  hr   avg_temp     avg_rh
# 0   25.0  18  35.766943  51.150415
# 1   25.0  19  35.459456  52.074476
# 2   25.0  20  35.368729  53.997419
# 3   25.0  21  35.071550  52.630291
# 4   25.0  22  34.868208  51.169653
# ..   ...  ..        ...        ...
# 80  30.0  12  34.475193  59.206796
# 81  30.0  13  34.279936  61.874368
# 82  30.0  14  34.654127  61.671332
# 83  30.0  15  33.762957  66.813327
# 84  30.0  16  32.575926  71.859259
#
# [85 rows x 4 columns]

# %%
mobiledf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()['day']
# Out:
# 0     25.0
# 1     25.0
# 2     25.0
# 3     25.0
# 4     25.0
#       ...
# 80    30.0
# 81    30.0
# 82    30.0
# 83    30.0
# 84    30.0
# Name: day, Length: 85, dtype: float64

# %%
(mobiledf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()).isnull().sum()
# Out:
# day         0
# hr          0
# avg_temp    0
# avg_rh      0
# dtype: int64

# %%
plt.figure(figsize=(20,12))
splot=sns.barplot(x=mobiledf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()['day'],y=mobiledf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()['avg_temp'],hue=mobiledf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()['hr'],palette='Greens')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-234-443257097121> in <module>
#       2 splot=sns.barplot(x=mobiledf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()['day'],y=mobiledf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()['avg_temp'],hue=mobiledf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()['hr'],palette='Greens')
#       3 for p in splot.patches:
# ----> 4     splot.annotate(format(round(p.get_height()), '.0f'),
#       5                    (p.get_x() + p.get_width() / 2., p.get_height()),
#       6                    ha='center', va='center',
#
# ValueError: cannot convert float NaN to integer

# %%
(stationarydf.isnull().sum()/stationarydf.shape[0])*100
# Out:
# DF_PM1       0.000000
# DF_PM25      0.000000
# DF_PM10      0.000000
# name         0.000000
# lat          0.000000
# NSO          0.000000
# lon          0.000000
# EWO          0.000000
# Alt          0.000000
# sog          0.000000
# cog          0.000000
# hdop         0.000000
# vdop         0.000000
# pdop         0.000000
# D_Time       0.000000
# DHT_RH      24.862851
# DHT_TEMP    24.862851
# AHT_RH      60.814983
# AHT_TEMP    60.814983
# SPS_PM1     97.808170
# SPS_PM25    97.808170
# SPS_PM10    97.808170
# month        0.000000
# day          0.000000
# time         0.000000
# dtype: float64

# %%
stationarydf['hr']=stationarydf['D_Time'].dt.hour
stationarydf
# Out:
# <ipython-input-241-916c27ce74f5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stationarydf['hr']=stationarydf['D_Time'].dt.hour
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO  Alt   sog  \
# 8929     15.0     20.0     28.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8930     15.0     20.0     28.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8931     14.0     19.0     27.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8932     14.0     19.0     27.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8933     14.0     19.0     27.0   S2   0.000000   N   0.000000   E  0.0  0.00
# ...       ...      ...      ...  ...        ...  ..        ...  ..  ...   ...
# ...

# %%
#dropping the sps sensor values
stationarydf.drop(columns=['SPS_PM1','SPS_PM25','SPS_PM10'],inplace=True)
# Out:
# C:\Users\jbroh\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
stationarydf
# Out:
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO  Alt   sog  \
# 8929     15.0     20.0     28.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8930     15.0     20.0     28.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8931     14.0     19.0     27.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8932     14.0     19.0     27.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8933     14.0     19.0     27.0   S2   0.000000   N   0.000000   E  0.0  0.00
# ...       ...      ...      ...  ...        ...  ..        ...  ..  ...   ...
# 84499    18.0     23.0     31.0   S9  12.991332   N  80.233410   E  6.4  0.43
# 84500    18.0     23.0     31.0   S9  12.991341   N  80.233414   E  6.1  0.17
# 84501    18.0     23.0     31.0   S9  12.991329   N  80.233393   E  2.1  0.65
# 84502    18.0     23.0     31.0   S9  12.991329   N  80.233393   E  2.1  0.65
# 84503    19.0     26.0     33.0   S9  12.991311   N  80.233415   E  6.0  0.07
#
# ...

# %%
stationarydf['Temp']=stationarydf[['AHT_TEMP','DHT_TEMP']].max(axis=1)
stationarydf['Rh']=stationarydf[['AHT_RH','DHT_RH']].max(axis=1)
stationarydf
# Out:
# <ipython-input-245-c8d74993084b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stationarydf['Temp']=stationarydf[['AHT_TEMP','DHT_TEMP']].max(axis=1)
# <ipython-input-245-c8d74993084b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stationarydf['Rh']=stationarydf[['AHT_RH','DHT_RH']].max(axis=1)
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO  Alt   sog  \
# 8929     15.0     20.0     28.0   S2   0.000000   N   0.000000   E  0.0  0.00
# ...

# %%
(stationarydf.isnull().sum()/stationarydf.shape[0])*100
# Out:
# DF_PM1       0.000000
# DF_PM25      0.000000
# DF_PM10      0.000000
# name         0.000000
# lat          0.000000
# NSO          0.000000
# lon          0.000000
# EWO          0.000000
# Alt          0.000000
# sog          0.000000
# cog          0.000000
# hdop         0.000000
# vdop         0.000000
# pdop         0.000000
# D_Time       0.000000
# DHT_RH      24.862851
# DHT_TEMP    24.862851
# AHT_RH      60.814983
# AHT_TEMP    60.814983
# month        0.000000
# day          0.000000
# time         0.000000
# hr           0.000000
# Temp         0.000000
# Rh           0.000000
# dtype: float64

# %%
#dropping the Dht rh and dht temo 4 columns
stationarydf.drop(columns=['DHT_RH','DHT_TEMP','AHT_RH','AHT_TEMP'],inplace=True)
stationarydf
# Out:
# C:\Users\jbroh\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO  Alt   sog  \
# 8929     15.0     20.0     28.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8930     15.0     20.0     28.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8931     14.0     19.0     27.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8932     14.0     19.0     27.0   S2   0.000000   N   0.000000   E  0.0  0.00
# 8933     14.0     19.0     27.0   S2   0.000000   N   0.000000   E  0.0  0.00
# ...       ...      ...      ...  ...        ...  ..        ...  ..  ...   ...
# 84499    18.0     23.0     31.0   S9  12.991332   N  80.233410   E  6.4  0.43
# ...

# %%
stationarydf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()
# Out:
#      day  hr   avg_temp     avg_rh
# 0   25.0  18  30.043640  75.709037
# 1   25.0  19  29.967358  75.852661
# 2   25.0  20  29.807369  75.388989
# 3   25.0  21  29.550421  73.740644
# 4   25.0  22  29.152328  71.322012
# 5   25.0  23  28.813811  71.021891
# 6   26.0   0  28.531457  72.953002
# 7   26.0   1  29.095836  73.196142
# 8   26.0   2  30.478442  71.520427
# 9   26.0   3  32.237943  66.604734
# 10  26.0   4  33.912656  62.309742
# 11  26.0   5  35.497505  58.755619
# 12  26.0   6  37.188211  55.012497
# 13  26.0   7  38.010979  53.610630
# 14  26.0   8  36.843483  59.173952

# %%
plt.figure(figsize=(20,12))
splot=sns.barplot(x=stationarydf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()['day'],y=stationarydf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()['avg_temp'],hue=stationarydf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()['hr'],palette='Greens')

# %%
sns.histplot(stationarydf['Rh'])
# Out:
# <AxesSubplot:xlabel='Rh', ylabel='Count'>

# %%
#greater than 80 Rh filling with avg
stationarydf.loc[stationarydf['Rh']>80,'Rh']=stationarydf['Rh'].mode()
# Out:
# C:\Users\jbroh\anaconda3\lib\site-packages\pandas\core\indexing.py:1700: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, v, pi)

# %%
sns.histplot(stationarydf['Rh'])
# Out:
# <AxesSubplot:xlabel='Rh', ylabel='Count'>

# %%
ndf=pd.concat((mobiledf,stationarydf),axis=0)
ndf.reset_index()
# Out:
#        index  DF_PM1  DF_PM25  DF_PM10 name        lat NSO        lon EWO  \
# 0         90    12.0     16.0     23.0   M5   0.000000   N   0.000000   E
# 1         91    12.0     16.0     23.0   M5   0.000000   N   0.000000   E
# 2         92    12.0     16.0     22.0   M5   0.000000   N   0.000000   E
# 3         93    12.0     16.0     22.0   M5   0.000000   N   0.000000   E
# 4         94    12.0     16.0     22.0   M5   0.000000   N   0.000000   E
# ...      ...     ...      ...      ...  ...        ...  ..        ...  ..
# 75334  84499    18.0     23.0     31.0   S9  12.991332   N  80.233410   E
# 75335  84500    18.0     23.0     31.0   S9  12.991341   N  80.233414   E
# 75336  84501    18.0     23.0     31.0   S9  12.991329   N  80.233393   E
# 75337  84502    18.0     23.0     31.0   S9  12.991329   N  80.233393   E
# 75338  84503    19.0     26.0     33.0   S9  12.991311   N  80.233415   E
#
#        Alt  ...   hdop   vdop   pdop              D_Time  month   day  \
# ...

# %%
ndf.isnull().sum()/ndf.shape[0]
# Out:
# DF_PM1     0.0
# DF_PM25    0.0
# DF_PM10    0.0
# name       0.0
# lat        0.0
# NSO        0.0
# lon        0.0
# EWO        0.0
# Alt        0.0
# sog        0.0
# cog        0.0
# hdop       0.0
# vdop       0.0
# pdop       0.0
# D_Time     0.0
# month      0.0
# day        0.0
# time       0.0
# Temp       0.0
# Rh         0.0
# hr         0.0
# dtype: float64

# %%
ndf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()
# Out:
#      day  hr   avg_temp     avg_rh
# 0   25.0  18  30.966192  71.750378
# 1   25.0  19  30.803222  72.233766
# 2   25.0  20  30.699285  71.958265
# 3   25.0  21  30.322071  70.790195
# 4   25.0  22  29.799267  69.041111
# ..   ...  ..        ...        ...
# 85  30.0  12  34.475193  59.206796
# 86  30.0  13  34.279936  61.874368
# 87  30.0  14  34.654127  61.671332
# 88  30.0  15  33.762957  66.813327
# 89  30.0  16  32.575926  71.859259
#
# [90 rows x 4 columns]

# %%
(ndf.groupby('day').agg('mean').reset_index())
# Out:
#     day     DF_PM1    DF_PM25    DF_PM10        lat        lon        Alt  \
# 0  25.0  18.511024  29.179184  32.672523   8.864063  54.741456  -2.149247
# 1  26.0  15.764604  20.463785  25.823981   8.009397  49.411425   6.603110
# 2  27.0   7.922110  10.969391  14.087182   9.342107  57.657058   9.559511
# 3  28.0  25.422260  33.258949  43.161298  10.874607  66.969777  10.043456
# 4  29.0  15.792285  21.318991  28.325562  10.630224  65.508945   6.305914
# 5  30.0  19.468222  25.768087  33.692698  10.570887  65.226527   6.339875
#
#          sog         cog       hdop       vdop       pdop  month       Temp  \
# 0   1.379656  181.306059  43.127784  43.454218  43.920237    5.0  30.274381
# 1   3.135517  409.951743  50.435688  50.867578  51.204820    5.0  33.800791
# 2   4.964529   89.671279  29.025056  30.016163  30.341632    5.0  36.267174
# 3  10.656255  125.368465  19.808073  20.543849  20.938372    5.0  37.285814
# ...

# %%
plt.ylim(-1,50)
sns.barplot((ndf.groupby('day').agg('mean').reset_index())['day'],(ndf.groupby('day').agg('mean').reset_index())['Temp'])
plt.ylabel('avg temp')
plt.show()

plt.ylim(-1,50)
sns.barplot((ndf.groupby('day').agg('max').reset_index())['day'],(ndf.groupby('day').agg('max').reset_index())['Temp'])
plt.ylabel('max temp')
plt.show()

plt.ylim(-1,50)
sns.barplot((ndf.groupby('day').agg('min').reset_index())['day'],(ndf.groupby('day').agg('min').reset_index())['Temp'])
plt.ylabel('min temp')
plt.show()
# Out:
# C:\Users\jbroh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\jbroh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\jbroh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.ylim(-1,90)
sns.barplot((ndf.groupby('day').agg('mean').reset_index())['day'],(ndf.groupby('day').agg('mean').reset_index())['Rh'])
plt.ylabel('avg rh')
plt.show()

plt.ylim(-1,90)
sns.barplot((ndf.groupby('day').agg('max').reset_index())['day'],(ndf.groupby('day').agg('max').reset_index())['Rh'])
plt.ylabel('max rh')
plt.show()

plt.ylim(-1,90)
sns.barplot((ndf.groupby('day').agg('min').reset_index())['day'],(ndf.groupby('day').agg('min').reset_index())['Rh'])
plt.ylabel('min rh')
plt.show()
# Out:
# C:\Users\jbroh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\jbroh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\jbroh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ndf.groupby(['day','hr']).agg('mean').reset_index()
# Out:
#      day  hr     DF_PM1    DF_PM25    DF_PM10        lat        lon  \
# 0   25.0  18  14.543796  20.069951  27.198297   8.923233  55.096514
# 1   25.0  19  14.335993  19.651120  26.468855   8.878439  54.824159
# 2   25.0  20  17.455569  23.361229  30.392270   8.924424  55.105854
# 3   25.0  21  22.383080  29.404738  36.175973   8.840904  54.600904
# 4   25.0  22  21.319267  27.814851  33.504743   8.617231  53.226345
# ..   ...  ..        ...        ...        ...        ...        ...
# 85  30.0  12  12.127072  16.232044  19.900552   6.818389  42.110102
# 86  30.0  13  17.461538  23.444139  30.619963  12.013761  74.360632
# 87  30.0  14  10.454148  14.395197  19.707424  12.908814  80.239236
# 88  30.0  15   9.509728  13.377432  18.091440  12.935536  80.233005
# 89  30.0  16  25.185185  33.259259  44.518519  12.970372  80.214243
#
#           Alt        sog         cog       hdop       vdop       pdop  month  \
# ...

# %%
plt.figure(figsize=(20,12))
splot=sns.barplot(x=ndf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()['day'],y=ndf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()['avg_temp'],hue=ndf.groupby(['day','hr']).agg(avg_temp=('Temp','mean'),avg_rh=('Rh','mean')).reset_index()['hr'],palette='Greens')
